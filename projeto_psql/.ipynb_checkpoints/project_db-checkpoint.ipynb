# %% [markdown]
# # Objetivo
#
# Dada uma planilha em Excel, inserir os dados da planilha num banco de dados PostgreSQL.
#
# Dica: você pode usar Python junto com psycopg2 para se conectar no PostgreSQL.
#
# Passos:
#
# * Criar uma virtualenv
#
# * Instalar psycopg2
#
# * Ler os dados da planilha Excel
#
# * Tratar os dados, se necessário
# * Inserir os dados no banco PostgreSQL
# * Coloque seu projeto no Gitlab, ou Github pessoal e me manda o link do repositório

# %% [markdown]
# # Dependências

# %% [markdown]
# ## Biblioteca

# %%
import psycopg2
import pandas as pd
from decouple import config

# %% [markdown]
# ## Dados e Constantes

# %%
df = pd.read_excel('categorias.xlsx')
df_1 = pd.read_excel('produtos.xlsx')

# %%
#tabela categoria
df.head()
# Out:
#    id   categoria
# 0   1     bebidas
# 1   2  sobremesas
# 2   3     cereais
# 3   4       frios
# 4   5     limpeza

# %%
#Tabela produtos
df_1.head()
# Out:
#    id          produto  preco
# 0   1              uva   2.59
# 1   2      Suco de uva  10.47
# 2   3    Suco de manga  10.47
# 3   4     Suco de maça  10.47
# 4   5  Suco de laranja  10.47

# %% [markdown]
# ## Inserindo os dados no banco Psql

# %%
try:
    connection = psycopg2.connect(user = "my_usuario",
                                  password = config("PASSAWORD"),
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "my_db")

    cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("You are connected to - ", record,"\n")

except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
# Out:
# {'user': 'my_usuario', 'dbname': 'my_db', 'host': '127.0.0.1', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.9 (Ubuntu 11.9-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-10ubuntu2) 9.3.0, 64-bit',)

# %%
cur = connection.cursor()

# %%
#Criando tabela para categoria
cur.execute("""CREATE TABLE IF NOT EXISTS categoria (id SERIAL PRIMARY KEY, nome VARCHAR(50));""")

# %%
for i,row in df.iterrows():
    name = row["categoria"]
    cur.execute(f"INSERT INTO categoria (nome) VALUES ('{name}')")

# %%
#cur.execute("drop table produtos")

# %%
connection.commit()

# %%
cur.execute("SELECT * FROM categoria;")
cur.fetchall()
# Out:
# [(1, 'bebidas'),
#  (2, 'sobremesas'),
#  (3, 'cereais'),
#  (4, 'frios'),
#  (5, 'limpeza'),
#  (6, 'hortifruti'),
#  (7, 'perfumaria'),
#  (8, 'mercearia'),
#  (9, 'bazar'),
#  (10, 'pet shop')]

# %%
#Criando tabela para produtos. 
cur.execute("""CREATE TABLE IF NOT EXISTS produtos(id SERIAL PRIMARY KEY, nome_produto VARCHAR(50), valor_produto INTEGER);""")

# %%
for i, row in df_1.iterrows():
    nome_produto = row["produto"]
    valor_produto = row["preco"]
    cur.execute(f"INSERT INTO produtos (nome_produto, valor_produto) VALUES ('{nome_produto}','{valor_produto}')")

# %%
connection.commit()

# %%
cur.execute("SELECT * FROM produtos;")
cur.fetchall()
# Out:
# [(1, 'uva', Decimal('2.59')),
#  (2, 'Suco de uva', Decimal('10.47')),
#  (3, 'Suco de manga', Decimal('10.47')),
#  (4, 'Suco de maça', Decimal('10.47')),
#  (5, 'Suco de laranja', Decimal('10.47')),
#  (6, 'shampoo', Decimal('3.97')),
#  (7, 'sardinha enlatada', Decimal('8.63')),
#  (8, 'sandália Havaianas', Decimal('4.56')),
#  (9, 'sabonete', Decimal('2.75')),
#  (10, 'Sabão em pó', Decimal('17.93')),
#  (11, 'Sabão em barra', Decimal('1.75')),
#  (12, 'Ração para gato', Decimal('14.96')),
#  (13, 'Ração para cachorro', Decimal('8.63')),
#  (14, 'quinoa', Decimal('7.12')),
#  (15, 'Queijo mussarela', Decimal('5.33')),
#  (16, 'Queijo frescal', Decimal('5.55')),
#  (17, 'Pudim', Decimal('2.55')),
#  (18, 'Petit Gateau', Decimal('6.77')),
#  (19, 'óleo de soja', Decimal('4.6')),
#  (20, 'óleo de girassol', Decimal('16.85')),
#  (21, 'mortadela', Decimal('6.39')),
#  (22, 'melão', Decimal('1.12')),
#  (23, 'melancia', Decimal('2.1')),
#  (24, 'manga', Decimal('15.41')),
#  (25, 'maionese', Decimal('3.32')),
#  (26, 'macarrão', Decimal('5.4')),
#  (27, 'maçã', Decimal('3.14')),
#  (28, 'linhaça', Decimal('5.3')),
#  (29, 'leite', Decimal('10.84')),
#  (30, 'laranja', Decimal('3.1')),
#  (31, 'Itubaina', Decimal('2.8')),
#  (32, 'granola', Decimal('7.08')),
#  (33, 'Gelatina', Decimal('7.42')),
#  (34, 'flocos de milho', Decimal('13.61')),
#  (35, 'feijão', Decimal('8.9')),
#  (36, 'farinha de trigo', Decimal('8.82')),
#  (37, 'Fanta Uva', Decimal('3.96')),
#  (38, 'Fanta Laranja', Decimal('3.49')),
#  (39, 'extrato de tomate', Decimal('1.12')),
#  (40, 'escova dental', Decimal('10.72')),
#  (41, 'Detergente', Decimal('5.29')),
#  (42, 'desodorante', Decimal('2.95')),
#  (43, 'Desinfetante', Decimal('4.69')),
#  (44, 'creme dental', Decimal('1.45')),
#  (45, 'creme de barbear', Decimal('2.48')),
#  (46, 'condicionador', Decimal('9.0')),
#  (47, 'Coleira', Decimal('11.81')),
#  (48, 'Coca-Cola', Decimal('3.49')),
#  (49, 'chá', Decimal('4.98')),
#  (50, 'centeio', Decimal('8.9')),
#  (51, 'Camiseta branca', Decimal('1.78')),
#  (52, 'café', Decimal('7.08')),
#  (53, 'Bola de morder', Decimal('5.96')),
#  (54, 'Bananinha', Decimal('0.86')),
#  (55, 'banana', Decimal('1.71')),
#  (56, 'azeite', Decimal('3.35')),
#  (57, 'aveia', Decimal('10.03')),
#  (58, 'atum enlatado', Decimal('1.7')),
#  (59, 'arroz', Decimal('5.5')),
#  (60, 'Apresuntado', Decimal('4.82')),
#  (61, 'Ambrosia', Decimal('2.55')),
#  (62, 'Água sanitária', Decimal('13.89')),
#  (63, 'abacaxi', Decimal('1.02')),
#  (64, 'abacate', Decimal('6.34')),
#  (65, 'uva', Decimal('2.59')),
#  (66, 'Suco de uva', Decimal('10.47')),
#  (67, 'Suco de manga', Decimal('10.47')),
#  (68, 'Suco de maça', Decimal('10.47')),
#  (69, 'Suco de laranja', Decimal('10.47')),
#  (70, 'shampoo', Decimal('3.97')),
#  (71, 'sardinha enlatada', Decimal('8.63')),
#  (72, 'sandália Havaianas', Decimal('4.56')),
#  (73, 'sabonete', Decimal('2.75')),
#  (74, 'Sabão em pó', Decimal('17.93')),
#  (75, 'Sabão em barra', Decimal('1.75')),
#  (76, 'Ração para gato', Decimal('14.96')),
#  (77, 'Ração para cachorro', Decimal('8.63')),
#  (78, 'quinoa', Decimal('7.12')),
#  (79, 'Queijo mussarela', Decimal('5.33')),
#  (80, 'Queijo frescal', Decimal('5.55')),
#  (81, 'Pudim', Decimal('2.55')),
#  (82, 'Petit Gateau', Decimal('6.77')),
#  (83, 'óleo de soja', Decimal('4.6')),
#  (84, 'óleo de girassol', Decimal('16.85')),
#  (85, 'mortadela', Decimal('6.39')),
#  (86, 'melão', Decimal('1.12')),
#  (87, 'melancia', Decimal('2.1')),
#  (88, 'manga', Decimal('15.41')),
#  (89, 'maionese', Decimal('3.32')),
#  (90, 'macarrão', Decimal('5.4')),
#  (91, 'maçã', Decimal('3.14')),
#  (92, 'linhaça', Decimal('5.3')),
#  (93, 'leite', Decimal('10.84')),
#  (94, 'laranja', Decimal('3.1')),
#  (95, 'Itubaina', Decimal('2.8')),
#  (96, 'granola', Decimal('7.08')),
#  (97, 'Gelatina', Decimal('7.42')),
#  (98, 'flocos de milho', Decimal('13.61')),
#  (99, 'feijão', Decimal('8.9')),
#  (100, 'farinha de trigo', Decimal('8.82')),
#  (101, 'Fanta Uva', Decimal('3.96')),
#  (102, 'Fanta Laranja', Decimal('3.49')),
#  (103, 'extrato de tomate', Decimal('1.12')),
#  (104, 'escova dental', Decimal('10.72')),
#  (105, 'Detergente', Decimal('5.29')),
#  (106, 'desodorante', Decimal('2.95')),
#  (107, 'Desinfetante', Decimal('4.69')),
#  (108, 'creme dental', Decimal('1.45')),
#  (109, 'creme de barbear', Decimal('2.48')),
#  (110, 'condicionador', Decimal('9.0')),
#  (111, 'Coleira', Decimal('11.81')),
#  (112, 'Coca-Cola', Decimal('3.49')),
#  (113, 'chá', Decimal('4.98')),
#  (114, 'centeio', Decimal('8.9')),
#  (115, 'Camiseta branca', Decimal('1.78')),
#  (116, 'café', Decimal('7.08')),
#  (117, 'Bola de morder', Decimal('5.96')),
#  (118, 'Bananinha', Decimal('0.86')),
#  (119, 'banana', Decimal('1.71')),
#  (120, 'azeite', Decimal('3.35')),
#  (121, 'aveia', Decimal('10.03')),
#  (122, 'atum enlatado', Decimal('1.7')),
#  (123, 'arroz', Decimal('5.5')),
#  (124, 'Apresuntado', Decimal('4.82')),
#  (125, 'Ambrosia', Decimal('2.55')),
#  (126, 'Água sanitária', Decimal('13.89')),
#  (127, 'abacaxi', Decimal('1.02')),
#  (128, 'abacate', Decimal('6.34')),
#  (129, 'uva', Decimal('2.59')),
#  (130, 'Suco de uva', Decimal('10.47')),
#  (131, 'Suco de manga', Decimal('10.47')),
#  (132, 'Suco de maça', Decimal('10.47')),
#  (133, 'Suco de laranja', Decimal('10.47')),
#  (134, 'shampoo', Decimal('3.97')),
#  (135, 'sardinha enlatada', Decimal('8.63')),
#  (136, 'sandália Havaianas', Decimal('4.56')),
#  (137, 'sabonete', Decimal('2.75')),
#  (138, 'Sabão em pó', Decimal('17.93')),
#  (139, 'Sabão em barra', Decimal('1.75')),
#  (140, 'Ração para gato', Decimal('14.96')),
#  (141, 'Ração para cachorro', Decimal('8.63')),
#  (142, 'quinoa', Decimal('7.12')),
#  (143, 'Queijo mussarela', Decimal('5.33')),
#  (144, 'Queijo frescal', Decimal('5.55')),
#  (145, 'Pudim', Decimal('2.55')),
#  (146, 'Petit Gateau', Decimal('6.77')),
#  (147, 'óleo de soja', Decimal('4.6')),
#  (148, 'óleo de girassol', Decimal('16.85')),
#  (149, 'mortadela', Decimal('6.39')),
#  (150, 'melão', Decimal('1.12')),
#  (151, 'melancia', Decimal('2.1')),
#  (152, 'manga', Decimal('15.41')),
#  (153, 'maionese', Decimal('3.32')),
#  (154, 'macarrão', Decimal('5.4')),
#  (155, 'maçã', Decimal('3.14')),
#  (156, 'linhaça', Decimal('5.3')),
#  (157, 'leite', Decimal('10.84')),
#  (158, 'laranja', Decimal('3.1')),
#  (159, 'Itubaina', Decimal('2.8')),
#  (160, 'granola', Decimal('7.08')),
#  (161, 'Gelatina', Decimal('7.42')),
#  (162, 'flocos de milho', Decimal('13.61')),
#  (163, 'feijão', Decimal('8.9')),
#  (164, 'farinha de trigo', Decimal('8.82')),
#  (165, 'Fanta Uva', Decimal('3.96')),
#  (166, 'Fanta Laranja', Decimal('3.49')),
#  (167, 'extrato de tomate', Decimal('1.12')),
#  (168, 'escova dental', Decimal('10.72')),
#  (169, 'Detergente', Decimal('5.29')),
#  (170, 'desodorante', Decimal('2.95')),
#  (171, 'Desinfetante', Decimal('4.69')),
#  (172, 'creme dental', Decimal('1.45')),
#  (173, 'creme de barbear', Decimal('2.48')),
#  (174, 'condicionador', Decimal('9.0')),
#  (175, 'Coleira', Decimal('11.81')),
#  (176, 'Coca-Cola', Decimal('3.49')),
#  (177, 'chá', Decimal('4.98')),
#  (178, 'centeio', Decimal('8.9')),
#  (179, 'Camiseta branca', Decimal('1.78')),
#  (180, 'café', Decimal('7.08')),
#  (181, 'Bola de morder', Decimal('5.96')),
#  (182, 'Bananinha', Decimal('0.86')),
#  (183, 'banana', Decimal('1.71')),
#  (184, 'azeite', Decimal('3.35')),
#  (185, 'aveia', Decimal('10.03')),
#  (186, 'atum enlatado', Decimal('1.7')),
#  (187, 'arroz', Decimal('5.5')),
#  (188, 'Apresuntado', Decimal('4.82')),
#  (189, 'Ambrosia', Decimal('2.55')),
#  (190, 'Água sanitária', Decimal('13.89')),
#  (191, 'abacaxi', Decimal('1.02')),
#  (192, 'abacate', Decimal('6.34')),
#  (193, 'uva', Decimal('2.59')),
#  (194, 'Suco de uva', Decimal('10.47')),
#  (195, 'Suco de manga', Decimal('10.47')),
#  (196, 'Suco de maça', Decimal('10.47')),
#  (197, 'Suco de laranja', Decimal('10.47')),
#  (198, 'shampoo', Decimal('3.97')),
#  (199, 'sardinha enlatada', Decimal('8.63')),
#  (200, 'sandália Havaianas', Decimal('4.56')),
#  (201, 'sabonete', Decimal('2.75')),
#  (202, 'Sabão em pó', Decimal('17.93')),
#  (203, 'Sabão em barra', Decimal('1.75')),
#  (204, 'Ração para gato', Decimal('14.96')),
#  (205, 'Ração para cachorro', Decimal('8.63')),
#  (206, 'quinoa', Decimal('7.12')),
#  (207, 'Queijo mussarela', Decimal('5.33')),
#  (208, 'Queijo frescal', Decimal('5.55')),
#  (209, 'Pudim', Decimal('2.55')),
#  (210, 'Petit Gateau', Decimal('6.77')),
#  (211, 'óleo de soja', Decimal('4.6')),
#  (212, 'óleo de girassol', Decimal('16.85')),
#  (213, 'mortadela', Decimal('6.39')),
#  (214, 'melão', Decimal('1.12')),
#  (215, 'melancia', Decimal('2.1')),
#  (216, 'manga', Decimal('15.41')),
#  (217, 'maionese', Decimal('3.32')),
#  (218, 'macarrão', Decimal('5.4')),
#  (219, 'maçã', Decimal('3.14')),
#  (220, 'linhaça', Decimal('5.3')),
#  (221, 'leite', Decimal('10.84')),
#  (222, 'laranja', Decimal('3.1')),
#  (223, 'Itubaina', Decimal('2.8')),
#  (224, 'granola', Decimal('7.08')),
#  (225, 'Gelatina', Decimal('7.42')),
#  (226, 'flocos de milho', Decimal('13.61')),
#  (227, 'feijão', Decimal('8.9')),
#  (228, 'farinha de trigo', Decimal('8.82')),
#  (229, 'Fanta Uva', Decimal('3.96')),
#  (230, 'Fanta Laranja', Decimal('3.49')),
#  (231, 'extrato de tomate', Decimal('1.12')),
#  (232, 'escova dental', Decimal('10.72')),
#  (233, 'Detergente', Decimal('5.29')),
#  (234, 'desodorante', Decimal('2.95')),
#  (235, 'Desinfetante', Decimal('4.69')),
#  (236, 'creme dental', Decimal('1.45')),
#  (237, 'creme de barbear', Decimal('2.48')),
#  (238, 'condicionador', Decimal('9.0')),
#  (239, 'Coleira', Decimal('11.81')),
#  (240, 'Coca-Cola', Decimal('3.49')),
#  (241, 'chá', Decimal('4.98')),
#  (242, 'centeio', Decimal('8.9')),
#  (243, 'Camiseta branca', Decimal('1.78')),
#  (244, 'café', Decimal('7.08')),
#  (245, 'Bola de morder', Decimal('5.96')),
#  (246, 'Bananinha', Decimal('0.86')),
#  (247, 'banana', Decimal('1.71')),
#  (248, 'azeite', Decimal('3.35')),
#  (249, 'aveia', Decimal('10.03')),
#  (250, 'atum enlatado', Decimal('1.7')),
#  (251, 'arroz', Decimal('5.5')),
#  (252, 'Apresuntado', Decimal('4.82')),
#  (253, 'Ambrosia', Decimal('2.55')),
#  (254, 'Água sanitária', Decimal('13.89')),
#  (255, 'abacaxi', Decimal('1.02')),
#  (256, 'abacate', Decimal('6.34')),
#  (257, 'uva', Decimal('2.59')),
#  (258, 'Suco de uva', Decimal('10.47')),
#  (259, 'Suco de manga', Decimal('10.47')),
#  (260, 'Suco de maça', Decimal('10.47')),
#  (261, 'Suco de laranja', Decimal('10.47')),
#  (262, 'shampoo', Decimal('3.97')),
#  (263, 'sardinha enlatada', Decimal('8.63')),
#  (264, 'sandália Havaianas', Decimal('4.56')),
#  (265, 'sabonete', Decimal('2.75')),
#  (266, 'Sabão em pó', Decimal('17.93')),
#  (267, 'Sabão em barra', Decimal('1.75')),
#  (268, 'Ração para gato', Decimal('14.96')),
#  (269, 'Ração para cachorro', Decimal('8.63')),
#  (270, 'quinoa', Decimal('7.12')),
#  (271, 'Queijo mussarela', Decimal('5.33')),
#  (272, 'Queijo frescal', Decimal('5.55')),
#  (273, 'Pudim', Decimal('2.55')),
#  (274, 'Petit Gateau', Decimal('6.77')),
#  (275, 'óleo de soja', Decimal('4.6')),
#  (276, 'óleo de girassol', Decimal('16.85')),
#  (277, 'mortadela', Decimal('6.39')),
#  (278, 'melão', Decimal('1.12')),
#  (279, 'melancia', Decimal('2.1')),
#  (280, 'manga', Decimal('15.41')),
#  (281, 'maionese', Decimal('3.32')),
#  (282, 'macarrão', Decimal('5.4')),
#  (283, 'maçã', Decimal('3.14')),
#  (284, 'linhaça', Decimal('5.3')),
#  (285, 'leite', Decimal('10.84')),
#  (286, 'laranja', Decimal('3.1')),
#  (287, 'Itubaina', Decimal('2.8')),
#  (288, 'granola', Decimal('7.08')),
#  (289, 'Gelatina', Decimal('7.42')),
#  (290, 'flocos de milho', Decimal('13.61')),
#  (291, 'feijão', Decimal('8.9')),
#  (292, 'farinha de trigo', Decimal('8.82')),
#  (293, 'Fanta Uva', Decimal('3.96')),
#  (294, 'Fanta Laranja', Decimal('3.49')),
#  (295, 'extrato de tomate', Decimal('1.12')),
#  (296, 'escova dental', Decimal('10.72')),
#  (297, 'Detergente', Decimal('5.29')),
#  (298, 'desodorante', Decimal('2.95')),
#  (299, 'Desinfetante', Decimal('4.69')),
#  (300, 'creme dental', Decimal('1.45')),
#  (301, 'creme de barbear', Decimal('2.48')),
#  (302, 'condicionador', Decimal('9.0')),
#  (303, 'Coleira', Decimal('11.81')),
#  (304, 'Coca-Cola', Decimal('3.49')),
#  (305, 'chá', Decimal('4.98')),
#  (306, 'centeio', Decimal('8.9')),
#  (307, 'Camiseta branca', Decimal('1.78')),
#  (308, 'café', Decimal('7.08')),
#  (309, 'Bola de morder', Decimal('5.96')),
#  (310, 'Bananinha', Decimal('0.86')),
#  (311, 'banana', Decimal('1.71')),
#  (312, 'azeite', Decimal('3.35')),
#  (313, 'aveia', Decimal('10.03')),
#  (314, 'atum enlatado', Decimal('1.7')),
#  (315, 'arroz', Decimal('5.5')),
#  (316, 'Apresuntado', Decimal('4.82')),
#  (317, 'Ambrosia', Decimal('2.55')),
#  (318, 'Água sanitária', Decimal('13.89')),
#  (319, 'abacaxi', Decimal('1.02')),
#  (320, 'abacate', Decimal('6.34')),
#  (321, 'uva', Decimal('2.59')),
#  (322, 'Suco de uva', Decimal('10.47')),
#  (323, 'Suco de manga', Decimal('10.47')),
#  (324, 'Suco de maça', Decimal('10.47')),
#  (325, 'Suco de laranja', Decimal('10.47')),
#  (326, 'shampoo', Decimal('3.97')),
#  (327, 'sardinha enlatada', Decimal('8.63')),
#  (328, 'sandália Havaianas', Decimal('4.56')),
#  (329, 'sabonete', Decimal('2.75')),
#  (330, 'Sabão em pó', Decimal('17.93')),
#  (331, 'Sabão em barra', Decimal('1.75')),
#  (332, 'Ração para gato', Decimal('14.96')),
#  (333, 'Ração para cachorro', Decimal('8.63')),
#  (334, 'quinoa', Decimal('7.12')),
#  (335, 'Queijo mussarela', Decimal('5.33')),
#  (336, 'Queijo frescal', Decimal('5.55')),
#  (337, 'Pudim', Decimal('2.55')),
#  (338, 'Petit Gateau', Decimal('6.77')),
#  (339, 'óleo de soja', Decimal('4.6')),
#  (340, 'óleo de girassol', Decimal('16.85')),
#  (341, 'mortadela', Decimal('6.39')),
#  (342, 'melão', Decimal('1.12')),
#  (343, 'melancia', Decimal('2.1')),
#  (344, 'manga', Decimal('15.41')),
#  (345, 'maionese', Decimal('3.32')),
#  (346, 'macarrão', Decimal('5.4')),
#  (347, 'maçã', Decimal('3.14')),
#  (348, 'linhaça', Decimal('5.3')),
#  (349, 'leite', Decimal('10.84')),
#  (350, 'laranja', Decimal('3.1')),
#  (351, 'Itubaina', Decimal('2.8')),
#  (352, 'granola', Decimal('7.08')),
#  (353, 'Gelatina', Decimal('7.42')),
#  (354, 'flocos de milho', Decimal('13.61')),
#  (355, 'feijão', Decimal('8.9')),
#  (356, 'farinha de trigo', Decimal('8.82')),
#  (357, 'Fanta Uva', Decimal('3.96')),
#  (358, 'Fanta Laranja', Decimal('3.49')),
#  (359, 'extrato de tomate', Decimal('1.12')),
#  (360, 'escova dental', Decimal('10.72')),
#  (361, 'Detergente', Decimal('5.29')),
#  (362, 'desodorante', Decimal('2.95')),
#  (363, 'Desinfetante', Decimal('4.69')),
#  (364, 'creme dental', Decimal('1.45')),
#  (365, 'creme de barbear', Decimal('2.48')),
#  (366, 'condicionador', Decimal('9.0')),
#  (367, 'Coleira', Decimal('11.81')),
#  (368, 'Coca-Cola', Decimal('3.49')),
#  (369, 'chá', Decimal('4.98')),
#  (370, 'centeio', Decimal('8.9')),
#  (371, 'Camiseta branca', Decimal('1.78')),
#  (372, 'café', Decimal('7.08')),
#  (373, 'Bola de morder', Decimal('5.96')),
#  (374, 'Bananinha', Decimal('0.86')),
#  (375, 'banana', Decimal('1.71')),
#  (376, 'azeite', Decimal('3.35')),
#  (377, 'aveia', Decimal('10.03')),
#  (378, 'atum enlatado', Decimal('1.7')),
#  (379, 'arroz', Decimal('5.5')),
#  (380, 'Apresuntado', Decimal('4.82')),
#  (381, 'Ambrosia', Decimal('2.55')),
#  (382, 'Água sanitária', Decimal('13.89')),
#  (383, 'abacaxi', Decimal('1.02')),
#  (384, 'abacate', Decimal('6.34')),
#  (385, 'uva', Decimal('2.59')),
#  (386, 'Suco de uva', Decimal('10.47')),
#  (387, 'Suco de manga', Decimal('10.47')),
#  (388, 'Suco de maça', Decimal('10.47')),
#  (389, 'Suco de laranja', Decimal('10.47')),
#  (390, 'shampoo', Decimal('3.97')),
#  (391, 'sardinha enlatada', Decimal('8.63')),
#  (392, 'sandália Havaianas', Decimal('4.56')),
#  (393, 'sabonete', Decimal('2.75')),
#  (394, 'Sabão em pó', Decimal('17.93')),
#  (395, 'Sabão em barra', Decimal('1.75')),
#  (396, 'Ração para gato', Decimal('14.96')),
#  (397, 'Ração para cachorro', Decimal('8.63')),
#  (398, 'quinoa', Decimal('7.12')),
#  (399, 'Queijo mussarela', Decimal('5.33')),
#  (400, 'Queijo frescal', Decimal('5.55')),
#  (401, 'Pudim', Decimal('2.55')),
#  (402, 'Petit Gateau', Decimal('6.77')),
#  (403, 'óleo de soja', Decimal('4.6')),
#  (404, 'óleo de girassol', Decimal('16.85')),
#  (405, 'mortadela', Decimal('6.39')),
#  (406, 'melão', Decimal('1.12')),
#  (407, 'melancia', Decimal('2.1')),
#  (408, 'manga', Decimal('15.41')),
#  (409, 'maionese', Decimal('3.32')),
#  (410, 'macarrão', Decimal('5.4')),
#  (411, 'maçã', Decimal('3.14')),
#  (412, 'linhaça', Decimal('5.3')),
#  (413, 'leite', Decimal('10.84')),
#  (414, 'laranja', Decimal('3.1')),
#  (415, 'Itubaina', Decimal('2.8')),
#  (416, 'granola', Decimal('7.08')),
#  (417, 'Gelatina', Decimal('7.42')),
#  (418, 'flocos de milho', Decimal('13.61')),
#  (419, 'feijão', Decimal('8.9')),
#  (420, 'farinha de trigo', Decimal('8.82')),
#  (421, 'Fanta Uva', Decimal('3.96')),
#  (422, 'Fanta Laranja', Decimal('3.49')),
#  (423, 'extrato de tomate', Decimal('1.12')),
#  (424, 'escova dental', Decimal('10.72')),
#  (425, 'Detergente', Decimal('5.29')),
#  (426, 'desodorante', Decimal('2.95')),
#  (427, 'Desinfetante', Decimal('4.69')),
#  (428, 'creme dental', Decimal('1.45')),
#  (429, 'creme de barbear', Decimal('2.48')),
#  (430, 'condicionador', Decimal('9.0')),
#  (431, 'Coleira', Decimal('11.81')),
#  (432, 'Coca-Cola', Decimal('3.49')),
#  (433, 'chá', Decimal('4.98')),
#  (434, 'centeio', Decimal('8.9')),
#  (435, 'Camiseta branca', Decimal('1.78')),
#  (436, 'café', Decimal('7.08')),
#  (437, 'Bola de morder', Decimal('5.96')),
#  (438, 'Bananinha', Decimal('0.86')),
#  (439, 'banana', Decimal('1.71')),
#  (440, 'azeite', Decimal('3.35')),
#  (441, 'aveia', Decimal('10.03')),
#  (442, 'atum enlatado', Decimal('1.7')),
#  (443, 'arroz', Decimal('5.5')),
#  (444, 'Apresuntado', Decimal('4.82')),
#  (445, 'Ambrosia', Decimal('2.55')),
#  (446, 'Água sanitária', Decimal('13.89')),
#  (447, 'abacaxi', Decimal('1.02')),
#  (448, 'abacate', Decimal('6.34')),
#  (449, 'uva', Decimal('2.59')),
#  (450, 'Suco de uva', Decimal('10.47')),
#  (451, 'Suco de manga', Decimal('10.47')),
#  (452, 'Suco de maça', Decimal('10.47')),
#  (453, 'Suco de laranja', Decimal('10.47')),
#  (454, 'shampoo', Decimal('3.97')),
#  (455, 'sardinha enlatada', Decimal('8.63')),
#  (456, 'sandália Havaianas', Decimal('4.56')),
#  (457, 'sabonete', Decimal('2.75')),
#  (458, 'Sabão em pó', Decimal('17.93')),
#  (459, 'Sabão em barra', Decimal('1.75')),
#  (460, 'Ração para gato', Decimal('14.96')),
#  (461, 'Ração para cachorro', Decimal('8.63')),
#  (462, 'quinoa', Decimal('7.12')),
#  (463, 'Queijo mussarela', Decimal('5.33')),
#  (464, 'Queijo frescal', Decimal('5.55')),
#  (465, 'Pudim', Decimal('2.55')),
#  (466, 'Petit Gateau', Decimal('6.77')),
#  (467, 'óleo de soja', Decimal('4.6')),
#  (468, 'óleo de girassol', Decimal('16.85')),
#  (469, 'mortadela', Decimal('6.39')),
#  (470, 'melão', Decimal('1.12')),
#  (471, 'melancia', Decimal('2.1')),
#  (472, 'manga', Decimal('15.41')),
#  (473, 'maionese', Decimal('3.32')),
#  (474, 'macarrão', Decimal('5.4')),
#  (475, 'maçã', Decimal('3.14')),
#  (476, 'linhaça', Decimal('5.3')),
#  (477, 'leite', Decimal('10.84')),
#  (478, 'laranja', Decimal('3.1')),
#  (479, 'Itubaina', Decimal('2.8')),
#  (480, 'granola', Decimal('7.08')),
#  (481, 'Gelatina', Decimal('7.42')),
#  (482, 'flocos de milho', Decimal('13.61')),
#  (483, 'feijão', Decimal('8.9')),
#  (484, 'farinha de trigo', Decimal('8.82')),
#  (485, 'Fanta Uva', Decimal('3.96')),
#  (486, 'Fanta Laranja', Decimal('3.49')),
#  (487, 'extrato de tomate', Decimal('1.12')),
#  (488, 'escova dental', Decimal('10.72')),
#  (489, 'Detergente', Decimal('5.29')),
#  (490, 'desodorante', Decimal('2.95')),
#  (491, 'Desinfetante', Decimal('4.69')),
#  (492, 'creme dental', Decimal('1.45')),
#  (493, 'creme de barbear', Decimal('2.48')),
#  (494, 'condicionador', Decimal('9.0')),
#  (495, 'Coleira', Decimal('11.81')),
#  (496, 'Coca-Cola', Decimal('3.49')),
#  (497, 'chá', Decimal('4.98')),
#  (498, 'centeio', Decimal('8.9')),
#  (499, 'Camiseta branca', Decimal('1.78')),
#  (500, 'café', Decimal('7.08')),
#  (501, 'Bola de morder', Decimal('5.96')),
#  (502, 'Bananinha', Decimal('0.86')),
#  (503, 'banana', Decimal('1.71')),
#  (504, 'azeite', Decimal('3.35')),
#  (505, 'aveia', Decimal('10.03')),
#  (506, 'atum enlatado', Decimal('1.7')),
#  (507, 'arroz', Decimal('5.5')),
#  (508, 'Apresuntado', Decimal('4.82')),
#  (509, 'Ambrosia', Decimal('2.55')),
#  (510, 'Água sanitária', Decimal('13.89')),
#  (511, 'abacaxi', Decimal('1.02')),
#  (512, 'abacate', Decimal('6.34')),
#  (513, 'uva', Decimal('2.59')),
#  (514, 'Suco de uva', Decimal('10.47')),
#  (515, 'Suco de manga', Decimal('10.47')),
#  (516, 'Suco de maça', Decimal('10.47')),
#  (517, 'Suco de laranja', Decimal('10.47')),
#  (518, 'shampoo', Decimal('3.97')),
#  (519, 'sardinha enlatada', Decimal('8.63')),
#  (520, 'sandália Havaianas', Decimal('4.56')),
#  (521, 'sabonete', Decimal('2.75')),
#  (522, 'Sabão em pó', Decimal('17.93')),
#  (523, 'Sabão em barra', Decimal('1.75')),
#  (524, 'Ração para gato', Decimal('14.96')),
#  (525, 'Ração para cachorro', Decimal('8.63')),
#  (526, 'quinoa', Decimal('7.12')),
#  (527, 'Queijo mussarela', Decimal('5.33')),
#  (528, 'Queijo frescal', Decimal('5.55')),
#  (529, 'Pudim', Decimal('2.55')),
#  (530, 'Petit Gateau', Decimal('6.77')),
#  (531, 'óleo de soja', Decimal('4.6')),
#  (532, 'óleo de girassol', Decimal('16.85')),
#  (533, 'mortadela', Decimal('6.39')),
#  (534, 'melão', Decimal('1.12')),
#  (535, 'melancia', Decimal('2.1')),
#  (536, 'manga', Decimal('15.41')),
#  (537, 'maionese', Decimal('3.32')),
#  (538, 'macarrão', Decimal('5.4')),
#  (539, 'maçã', Decimal('3.14')),
#  (540, 'linhaça', Decimal('5.3')),
#  (541, 'leite', Decimal('10.84')),
#  (542, 'laranja', Decimal('3.1')),
#  (543, 'Itubaina', Decimal('2.8')),
#  (544, 'granola', Decimal('7.08')),
#  (545, 'Gelatina', Decimal('7.42')),
#  (546, 'flocos de milho', Decimal('13.61')),
#  (547, 'feijão', Decimal('8.9')),
#  (548, 'farinha de trigo', Decimal('8.82')),
#  (549, 'Fanta Uva', Decimal('3.96')),
#  (550, 'Fanta Laranja', Decimal('3.49')),
#  (551, 'extrato de tomate', Decimal('1.12')),
#  (552, 'escova dental', Decimal('10.72')),
#  (553, 'Detergente', Decimal('5.29')),
#  (554, 'desodorante', Decimal('2.95')),
#  (555, 'Desinfetante', Decimal('4.69')),
#  (556, 'creme dental', Decimal('1.45')),
#  (557, 'creme de barbear', Decimal('2.48')),
#  (558, 'condicionador', Decimal('9.0')),
#  (559, 'Coleira', Decimal('11.81')),
#  (560, 'Coca-Cola', Decimal('3.49')),
#  (561, 'chá', Decimal('4.98')),
#  (562, 'centeio', Decimal('8.9')),
#  (563, 'Camiseta branca', Decimal('1.78')),
#  (564, 'café', Decimal('7.08')),
#  (565, 'Bola de morder', Decimal('5.96')),
#  (566, 'Bananinha', Decimal('0.86')),
#  (567, 'banana', Decimal('1.71')),
#  (568, 'azeite', Decimal('3.35')),
#  (569, 'aveia', Decimal('10.03')),
#  (570, 'atum enlatado', Decimal('1.7')),
#  (571, 'arroz', Decimal('5.5')),
#  (572, 'Apresuntado', Decimal('4.82')),
#  (573, 'Ambrosia', Decimal('2.55')),
#  (574, 'Água sanitária', Decimal('13.89')),
#  (575, 'abacaxi', Decimal('1.02')),
#  (576, 'abacate', Decimal('6.34')),
#  (577, 'uva', Decimal('2.59')),
#  (578, 'Suco de uva', Decimal('10.47')),
#  (579, 'Suco de manga', Decimal('10.47')),
#  (580, 'Suco de maça', Decimal('10.47')),
#  (581, 'Suco de laranja', Decimal('10.47')),
#  (582, 'shampoo', Decimal('3.97')),
#  (583, 'sardinha enlatada', Decimal('8.63')),
#  (584, 'sandália Havaianas', Decimal('4.56')),
#  (585, 'sabonete', Decimal('2.75')),
#  (586, 'Sabão em pó', Decimal('17.93')),
#  (587, 'Sabão em barra', Decimal('1.75')),
#  (588, 'Ração para gato', Decimal('14.96')),
#  (589, 'Ração para cachorro', Decimal('8.63')),
#  (590, 'quinoa', Decimal('7.12')),
#  (591, 'Queijo mussarela', Decimal('5.33')),
#  (592, 'Queijo frescal', Decimal('5.55')),
#  (593, 'Pudim', Decimal('2.55')),
#  (594, 'Petit Gateau', Decimal('6.77')),
#  (595, 'óleo de soja', Decimal('4.6')),
#  (596, 'óleo de girassol', Decimal('16.85')),
#  (597, 'mortadela', Decimal('6.39')),
#  (598, 'melão', Decimal('1.12')),
#  (599, 'melancia', Decimal('2.1')),
#  (600, 'manga', Decimal('15.41')),
#  (601, 'maionese', Decimal('3.32')),
#  (602, 'macarrão', Decimal('5.4')),
#  (603, 'maçã', Decimal('3.14')),
#  (604, 'linhaça', Decimal('5.3')),
#  (605, 'leite', Decimal('10.84')),
#  (606, 'laranja', Decimal('3.1')),
#  (607, 'Itubaina', Decimal('2.8')),
#  (608, 'granola', Decimal('7.08')),
#  (609, 'Gelatina', Decimal('7.42')),
#  (610, 'flocos de milho', Decimal('13.61')),
#  (611, 'feijão', Decimal('8.9')),
#  (612, 'farinha de trigo', Decimal('8.82')),
#  (613, 'Fanta Uva', Decimal('3.96')),
#  (614, 'Fanta Laranja', Decimal('3.49')),
#  (615, 'extrato de tomate', Decimal('1.12')),
#  (616, 'escova dental', Decimal('10.72')),
#  (617, 'Detergente', Decimal('5.29')),
#  (618, 'desodorante', Decimal('2.95')),
#  (619, 'Desinfetante', Decimal('4.69')),
#  (620, 'creme dental', Decimal('1.45')),
#  (621, 'creme de barbear', Decimal('2.48')),
#  (622, 'condicionador', Decimal('9.0')),
#  (623, 'Coleira', Decimal('11.81')),
#  (624, 'Coca-Cola', Decimal('3.49')),
#  (625, 'chá', Decimal('4.98')),
#  (626, 'centeio', Decimal('8.9')),
#  (627, 'Camiseta branca', Decimal('1.78')),
#  (628, 'café', Decimal('7.08')),
#  (629, 'Bola de morder', Decimal('5.96')),
#  (630, 'Bananinha', Decimal('0.86')),
#  (631, 'banana', Decimal('1.71')),
#  (632, 'azeite', Decimal('3.35')),
#  (633, 'aveia', Decimal('10.03')),
#  (634, 'atum enlatado', Decimal('1.7')),
#  (635, 'arroz', Decimal('5.5')),
#  (636, 'Apresuntado', Decimal('4.82')),
#  (637, 'Ambrosia', Decimal('2.55')),
#  (638, 'Água sanitária', Decimal('13.89')),
#  (639, 'abacaxi', Decimal('1.02')),
#  (640, 'abacate', Decimal('6.34')),
#  (641, 'uva', Decimal('2.59')),
#  (642, 'Suco de uva', Decimal('10.47')),
#  (643, 'Suco de manga', Decimal('10.47')),
#  (644, 'Suco de maça', Decimal('10.47')),
#  (645, 'Suco de laranja', Decimal('10.47')),
#  (646, 'shampoo', Decimal('3.97')),
#  (647, 'sardinha enlatada', Decimal('8.63')),
#  (648, 'sandália Havaianas', Decimal('4.56')),
#  (649, 'sabonete', Decimal('2.75')),
#  (650, 'Sabão em pó', Decimal('17.93')),
#  (651, 'Sabão em barra', Decimal('1.75')),
#  (652, 'Ração para gato', Decimal('14.96')),
#  (653, 'Ração para cachorro', Decimal('8.63')),
#  (654, 'quinoa', Decimal('7.12')),
#  (655, 'Queijo mussarela', Decimal('5.33')),
#  (656, 'Queijo frescal', Decimal('5.55')),
#  (657, 'Pudim', Decimal('2.55')),
#  (658, 'Petit Gateau', Decimal('6.77')),
#  (659, 'óleo de soja', Decimal('4.6')),
#  (660, 'óleo de girassol', Decimal('16.85')),
#  (661, 'mortadela', Decimal('6.39')),
#  (662, 'melão', Decimal('1.12')),
#  (663, 'melancia', Decimal('2.1')),
#  (664, 'manga', Decimal('15.41')),
#  (665, 'maionese', Decimal('3.32')),
#  (666, 'macarrão', Decimal('5.4')),
#  (667, 'maçã', Decimal('3.14')),
#  (668, 'linhaça', Decimal('5.3')),
#  (669, 'leite', Decimal('10.84')),
#  (670, 'laranja', Decimal('3.1')),
#  (671, 'Itubaina', Decimal('2.8')),
#  (672, 'granola', Decimal('7.08')),
#  (673, 'Gelatina', Decimal('7.42')),
#  (674, 'flocos de milho', Decimal('13.61')),
#  (675, 'feijão', Decimal('8.9')),
#  (676, 'farinha de trigo', Decimal('8.82')),
#  (677, 'Fanta Uva', Decimal('3.96')),
#  (678, 'Fanta Laranja', Decimal('3.49')),
#  (679, 'extrato de tomate', Decimal('1.12')),
#  (680, 'escova dental', Decimal('10.72')),
#  (681, 'Detergente', Decimal('5.29')),
#  (682, 'desodorante', Decimal('2.95')),
#  (683, 'Desinfetante', Decimal('4.69')),
#  (684, 'creme dental', Decimal('1.45')),
#  (685, 'creme de barbear', Decimal('2.48')),
#  (686, 'condicionador', Decimal('9.0')),
#  (687, 'Coleira', Decimal('11.81')),
#  (688, 'Coca-Cola', Decimal('3.49')),
#  (689, 'chá', Decimal('4.98')),
#  (690, 'centeio', Decimal('8.9')),
#  (691, 'Camiseta branca', Decimal('1.78')),
#  (692, 'café', Decimal('7.08')),
#  (693, 'Bola de morder', Decimal('5.96')),
#  (694, 'Bananinha', Decimal('0.86')),
#  (695, 'banana', Decimal('1.71')),
#  (696, 'azeite', Decimal('3.35')),
#  (697, 'aveia', Decimal('10.03')),
#  (698, 'atum enlatado', Decimal('1.7')),
#  (699, 'arroz', Decimal('5.5')),
#  (700, 'Apresuntado', Decimal('4.82')),
#  (701, 'Ambrosia', Decimal('2.55')),
#  (702, 'Água sanitária', Decimal('13.89')),
#  (703, 'abacaxi', Decimal('1.02')),
#  (704, 'abacate', Decimal('6.34')),
#  (705, 'uva', Decimal('2.59')),
#  (706, 'Suco de uva', Decimal('10.47')),
#  (707, 'Suco de manga', Decimal('10.47')),
#  (708, 'Suco de maça', Decimal('10.47')),
#  (709, 'Suco de laranja', Decimal('10.47')),
#  (710, 'shampoo', Decimal('3.97')),
#  (711, 'sardinha enlatada', Decimal('8.63')),
#  (712, 'sandália Havaianas', Decimal('4.56')),
#  (713, 'sabonete', Decimal('2.75')),
#  (714, 'Sabão em pó', Decimal('17.93')),
#  (715, 'Sabão em barra', Decimal('1.75')),
#  (716, 'Ração para gato', Decimal('14.96')),
#  (717, 'Ração para cachorro', Decimal('8.63')),
#  (718, 'quinoa', Decimal('7.12')),
#  (719, 'Queijo mussarela', Decimal('5.33')),
#  (720, 'Queijo frescal', Decimal('5.55')),
#  (721, 'Pudim', Decimal('2.55')),
#  (722, 'Petit Gateau', Decimal('6.77')),
#  (723, 'óleo de soja', Decimal('4.6')),
#  (724, 'óleo de girassol', Decimal('16.85')),
#  (725, 'mortadela', Decimal('6.39')),
#  (726, 'melão', Decimal('1.12')),
#  (727, 'melancia', Decimal('2.1')),
#  (728, 'manga', Decimal('15.41')),
#  (729, 'maionese', Decimal('3.32')),
#  (730, 'macarrão', Decimal('5.4')),
#  (731, 'maçã', Decimal('3.14')),
#  (732, 'linhaça', Decimal('5.3')),
#  (733, 'leite', Decimal('10.84')),
#  (734, 'laranja', Decimal('3.1')),
#  (735, 'Itubaina', Decimal('2.8')),
#  (736, 'granola', Decimal('7.08')),
#  (737, 'Gelatina', Decimal('7.42')),
#  (738, 'flocos de milho', Decimal('13.61')),
#  (739, 'feijão', Decimal('8.9')),
#  (740, 'farinha de trigo', Decimal('8.82')),
#  (741, 'Fanta Uva', Decimal('3.96')),
#  (742, 'Fanta Laranja', Decimal('3.49')),
#  (743, 'extrato de tomate', Decimal('1.12')),
#  (744, 'escova dental', Decimal('10.72')),
#  (745, 'Detergente', Decimal('5.29')),
#  (746, 'desodorante', Decimal('2.95')),
#  (747, 'Desinfetante', Decimal('4.69')),
#  (748, 'creme dental', Decimal('1.45')),
#  (749, 'creme de barbear', Decimal('2.48')),
#  (750, 'condicionador', Decimal('9.0')),
#  (751, 'Coleira', Decimal('11.81')),
#  (752, 'Coca-Cola', Decimal('3.49')),
#  (753, 'chá', Decimal('4.98')),
#  (754, 'centeio', Decimal('8.9')),
#  (755, 'Camiseta branca', Decimal('1.78')),
#  (756, 'café', Decimal('7.08')),
#  (757, 'Bola de morder', Decimal('5.96')),
#  (758, 'Bananinha', Decimal('0.86')),
#  (759, 'banana', Decimal('1.71')),
#  (760, 'azeite', Decimal('3.35')),
#  (761, 'aveia', Decimal('10.03')),
#  (762, 'atum enlatado', Decimal('1.7')),
#  (763, 'arroz', Decimal('5.5')),
#  (764, 'Apresuntado', Decimal('4.82')),
#  (765, 'Ambrosia', Decimal('2.55')),
#  (766, 'Água sanitária', Decimal('13.89')),
#  (767, 'abacaxi', Decimal('1.02')),
#  (768, 'abacate', Decimal('6.34'))]

# %%
cur.execute("DROP TABLE IF EXISTS produtos")

# %%
cur.execute("SELECT * FROM produtos;")
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-12-7566ff566976> in <module>
# ----> 1 cur.execute("SELECT * FROM produtos;")
#
# UndefinedTable: relation "produtos" does not exist
# LINE 1: SELECT * FROM produtos;
#                       ^
